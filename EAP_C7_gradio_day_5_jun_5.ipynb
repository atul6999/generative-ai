# %% [markdown]
# # Introduction to Gradio

# %% [markdown]
# ## Import the Libraries

# %%
import gradio as gr
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

import time

# %% [markdown]
# ---

# %% [markdown]
# ## Hello World App

# %%
def greet(name):
    return f"Hello, {name}!"

demo = gr.Interface(fn=greet, inputs="text", outputs="text")
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://0a4c6c7d31e7772d62.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0a4c6c7d31e7772d62.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---

# %% [markdown]
# ## Interface vs Blocks

# %% [markdown]
# ### Interface

# %%
def square(x):
    return x ** 2

demo = gr.Interface(fn=square, inputs="number", outputs="number")
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ffc464a8b60b8917fe.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ffc464a8b60b8917fe.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Blocks

# %%
# Blocks
# q: is it possible to get horizontal stacking via blocks? yes totally possible
with gr.Blocks() as demo:
    input_num = gr.Number(label="Input")
    output_num = gr.Number(label="Squared Output")
    button = gr.Button("Compute")

    button.click(lambda x: x**2, inputs=input_num, outputs=output_num)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://97a2ba939f551a6305.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://97a2ba939f551a6305.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---

# %% [markdown]
# ## Gradio Input and Output Components

# %% [markdown]
# ### Input

# %%
def show_inputs(text, image, audio):
    return f"You said: {text}", image, audio

demo = gr.Interface(
    fn=show_inputs,
    inputs=[
        gr.Textbox(label="Your Text"),
        gr.Image(label="Upload Image"),
        gr.Audio(label="Upload Audio")
    ],
    outputs=["text", "image", "audio"]
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://0ebc87d892fbba9771.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0ebc87d892fbba9771.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Output

# %%
def generate_outputs():
    df = pd.DataFrame({"A": [1, 2], "B": [3, 4]})
    markdown_text = "**Bold Text Example**"
    return df, markdown_text # exercise: flip the return order --  markdown_text, df

demo = gr.Interface(
    fn=generate_outputs,
    inputs=None,
    outputs=[gr.DataFrame(), gr.Markdown()]
)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://d8ed1ecea90ea6425d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d8ed1ecea90ea6425d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def compute_and_plot(x):
    squared = x ** 2

    fig, ax = plt.subplots()
    nums = np.arange(0, x+1)
    ax.plot(nums, nums**2, marker='o')
    ax.set_title("Square Numbers")
    ax.set_xlabel("Number")
    ax.set_ylabel("Squared Value")

    return squared, fig

with gr.Blocks() as demo:
    input_num = gr.Number(label="Input")
    output_num = gr.Number(label="Squared Output")
    plot_output = gr.Plot(label="Visualization")
    button = gr.Button("Compute")

    button.click(compute_and_plot, inputs=input_num, outputs=[output_num, plot_output])

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9b2e3e8e3d8af2b43f.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9b2e3e8e3d8af2b43f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---

# %% [markdown]
# ## Events Handling

# %%
def on_click(name):
    return f"Clicked! Hello, {name}"

def on_change(name):
    return f"Changed to: {name}"

with gr.Blocks() as demo:
    gr.Markdown("### Gradio Event Handling Demo")

    name_input = gr.Textbox(label="Enter your name", interactive=True)
    click_output = gr.Textbox(label="Click Output")
    change_output = gr.Textbox(label="Change Output")

    greet_btn = gr.Button("Click Me")

    # Events
    greet_btn.click(on_click, inputs=name_input, outputs=click_output)
    name_input.change(on_change, inputs=name_input, outputs=change_output)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9c5fe3aa42d04b2977.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9c5fe3aa42d04b2977.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Blocks

# %%
with gr.Blocks() as demo:
    with gr.Row():
        name = gr.Textbox(label="Name")
        age = gr.Number(label="Age")

    with gr.Row():
      greet_btn = gr.Button("Greet")
    with gr.Row():
      output = gr.Textbox()

    greet_btn.click(lambda n, a: f"Hello {n}, you're {a}!", [name, age], output)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://fa74789d84917de821.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fa74789d84917de821.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---

# %%
def stream_response(text):
    for word in text.split():
        yield word + " "
        time.sleep(0.3)

demo = gr.Interface(
    fn=stream_response,
    inputs=gr.Textbox(label="Enter sentence"),
    outputs=gr.Textbox(label="Streaming Output"),
    live=True,
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://c32b81a1ae6f9a4347.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c32b81a1ae6f9a4347.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
